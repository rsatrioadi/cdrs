# %%
import classdiagram as cd

g = cd.read_csv('sample_members.csv', 'sample_connections.csv')

# save to file
g.render(outfile='classdiagram-demo.png')

# in a jupyter notebook environment, this plots the diagram to the cell output
g
